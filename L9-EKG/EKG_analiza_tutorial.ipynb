# %% [markdown]
# ## Analiza sygnału EKG
# Procedura analizy sygnału EKG: celem jest określenie parametrów tętna (Heart Rate HR), zmięnność tętna (Heart Rate Variability HRV) oraz wydatku energetycznego (energy expenditure)

# %% [markdown]
# #### 1. Pomiar sygnału EKG
#  - zmierz sygnał EKG przez około 10 minut w pozycji "zrelaksowanej": EKG spoczynkowy;
#  - zmierz sygnał EKG przez około 10 minut, przez pierwsze 3 minuty pozostań zrelakoswoany, podejmij wysiłek fizyczny przez kolejne około 3 minuty (rower, rower stacjonarny?), pozostań zrelaksowany przez pozostały czas

# %% [markdown]
# #### 2. Import bibliotek

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack as f
import pandas as pd
import scipy.signal
import ekg_analyze_lib as ekglib

# %% [markdown]
# #### 3. Wczytanie danych pomiarowych z pliku

# %%
kolumny = ['ekg', 't']
rest_ekg = pd.read_csv('resting.txt', 
        names = kolumny, sep='\t', skiprows=5000, skipfooter=5000, engine='python')

# %%
print(rest_ekg.ekg)
# Out:
# 0         317
# 1         317
# 2         317
# 3         318
# 4         318
#          ...
# 328161    301
# 328162    302
# 328163    304
# 328164    306
# 328165    310
# Name: ekg, Length: 328166, dtype: int64

# %%
print(rest_ekg.t)
# Out:
# 0         327319
# 1         327320
# 2         327321
# 3         327322
# 4         327323
#            ...
# 328161    656964
# 328162    656965
# 328163    656966
# 328164    656967
# 328165    656968
# Name: t, Length: 328166, dtype: int64

# %%
#częstotliwość próbkowania
fs = 1000   

#zmiana ms na s
rest_ekg.t = (rest_ekg.t)/1000

# %%
print(rest_ekg.t)
# Out:
# 0         327.319
# 1         327.320
# 2         327.321
# 3         327.322
# 4         327.323
#            ...
# 328161    656.964
# 328162    656.965
# 328163    656.966
# 328164    656.967
# 328165    656.968
# Name: t, Length: 328166, dtype: float64

# %% [markdown]
# #### 4. Wizualizacja wyników pomiarów

# %%
plt.plot(rest_ekg.t, rest_ekg.ekg)
plt.title('EKG spoczynkowy')
plt.ylabel('EKG / a. u.')
plt.xlabel('t / s')
# Out:
# Text(0.5, 0, 't / s')

# %%
#zawężenie osi czasu
plt.plot(rest_ekg.t, rest_ekg.ekg)
plt.title('EKG spoczynkowy')
plt.ylabel('EKG / a. u.')
plt.xlabel('t / s')
plt.xlim(456,458)
# Out:
# (456.0, 458.0)

# %% [markdown]
# #### 5. Widmo sygnału

# %%
F = f.fft(rest_ekg.ekg)
N = len(rest_ekg.ekg)
freq = f.fftfreq(N, 1.0/fs) #wyznaczenie częstotliwoci próbek fft
mask = np.where(freq>=0)
F[0]=0  #wyzerowanie składowej stałej

# %%
print(F)
# Out:
# [    0.           +0.j         -4050.31184814+2736.63338717j
#  -4139.88524865 +439.47101239j ... -3798.56432334 +116.8857279j
#  -4139.88524865 -439.47101239j -4050.31184814-2736.63338717j]

# %%
#charakterystyka amplitudowa
plt.stem(freq[mask], 2*np.abs(F[mask])/N)
plt.ylabel('|H(f)|')
plt.xlabel('f / Hz')
# Out:
# Text(0.5, 0, 'f / Hz')

# %%
#skala logarytmiczna, zawężenie widma
plt.stem(freq[mask], 2*np.abs(F[mask])/N)
plt.ylabel('|H(f)|')
plt.xlabel('f / Hz')
#plt.yscale('log')
plt.xlim(0,100)
# Out:
# (0.0, 100.0)

# %% [markdown]
# #### 6. Filtracja sygnału (opcjonalnie)

# %%
#filtracja sygnału
fc = 50 #częstotliwoć odcięcia filtru
Wn = 2*fc/fs
b, a = scipy.signal.butter(4, Wn, 'low', analog=False)
ekg_filt = scipy.signal.filtfilt(b, a, rest_ekg.ekg)
plt.plot(rest_ekg.t, rest_ekg.ekg, rest_ekg.t, ekg_filt)
plt.xlabel('t / s')
plt.ylabel('EKG / a.u')
plt.xlim(400,405)
#plt.ylim(-2,3)
# Out:
# (400.0, 405.0)

# %% [markdown]
# #### 7. Określenie pozycji pików R

# %%
# użycie funkcji findpeaks()
pikiR,_ = scipy.signal.find_peaks(ekg_filt, height=360)
plt.plot(rest_ekg.t, ekg_filt)
plt.plot(rest_ekg.t[pikiR], ekg_filt[pikiR], 'x')
plt.xlabel('t / s')
plt.ylabel('EKG / a.u')
plt.xlim(365,375)
# Out:
# (365.0, 375.0)

# %% [markdown]
# #### 8. Określenie pozycji pików R z użyciem biblioteki ekg_analyze_lib

# %%
#poszukiwanie maksimów w pochodnej ekg
d_ekg, peaks_d_ekg = ekglib.decg_peaks(ekg_filt, rest_ekg.t)

# %%
#pozycje pików R w pochodnej
R_peaks_d_ekg = ekglib.d_ecg_peaks(d_ekg, peaks_d_ekg, rest_ekg.t, 0.4, 0.45)

# %%
#pozycja pików R
R_peaks = ekglib.Rwave_peaks(ekg_filt, d_ekg, R_peaks_d_ekg, rest_ekg.t)

# %% [markdown]
# #### 9. Obliczenie HR oraz HRV

# %%
# obliczenie interwałów
intervals = np.diff(R_peaks)

# %%
print(intervals)
# Out:
# [1.099 1.1   1.121 1.079 1.061 1.078 1.057 1.025 1.106 1.077 1.008 1.02
#  1.053 1.052 1.106 1.163 1.15  1.091 1.026 1.109 1.116 1.015 1.049 1.064
#  1.188 1.074 1.155 1.219 1.169 1.107 1.16  1.132 1.081 1.062 1.104 1.068
#  1.11  1.149 1.119 1.064 1.077 0.939 0.851 0.883 1.183 1.106 1.04  1.092
#  1.087 1.028 1.068 1.078 1.037 1.084 1.073 0.999 1.046 1.07  1.035 1.097
#  1.167 1.117 1.079 1.11  1.039 1.035 1.082 1.087 1.021 1.057 1.059 1.022
#  1.095 1.089 1.038 1.083 1.082 1.006 1.041 1.099 1.053 1.114 1.158 1.105
#  1.113 1.116 1.06  1.033 1.114 1.062 1.047 1.093 1.071 1.066 1.087 1.053
#  1.019 1.092 1.059 1.017 1.05  1.009 0.998 1.035 1.033 0.964 0.994 1.062
#  1.041 1.064 1.162 1.087 1.058 1.13  1.121 1.132 1.169 1.174 1.086 1.133
#  1.112 0.996 0.996 1.056 1.042 1.161 1.005 0.827 0.88  1.237 1.09  1.097
#  53.95683453 60.24096386 60.24096386 56.81818182 57.5815739  51.67958656
#  59.70149254 72.55139057 68.18181818 48.50444624 55.04587156 54.6946217
#  53.38078292 57.74783446 57.41626794 52.72407733 56.71077505 56.33802817
#  54.15162455 57.36137667 61.09979633 60.79027356 55.50416281 59.34718101
#  50.33557047 52.53940455 55.04587156 51.19453925 50.93378608 51.8134715
#  53.85996409 50.42016807 50.37783375 54.00540054 51.85825411 53.09734513
#  57.69230769 55.19779209 57.19733079 59.05511811 53.19148936 51.8134715
#  54.49591281 50.33557047 50.29337804 53.57142857 50.71851226 51.10732538
#  52.72407733 51.36986301 49.75124378 53.33333333 49.66887417 51.10732538
#  53.57142857 50.         52.31037489 56.49717514 56.02240896 66.81514477
#  73.26007326 72.02881152 50.25125628 53.05039788 56.71077505 54.05405405
#  54.49591281 58.36575875 53.28596803 52.67778753 57.03422053 55.60704356
#  54.894785   56.6572238  54.20054201 56.71077505 60.12024048 58.42259007
#  57.14285714 60.54490414 57.08848716 56.39097744 60.72874494 58.59375
#  59.28853755 63.35797254 62.43496358 62.5        64.1025641  61.09979633
#  59.05511811 61.60164271 60.97560976 61.28702758 63.89776358 62.56517205
#  62.82722513 66.15214994 64.79481641 61.53846154 61.41248721 62.30529595
#  59.17159763 57.63688761 59.64214712 58.82352941 60.06006006 64.1025641
#  62.30529595 56.55042413 59.28853755 63.62672322 60.         58.99705015
#  62.9590766  59.94005994 57.85920926 59.40594059 55.86592179 52.81690141
#  56.44402634 54.24954792 51.50214592 53.71530886 51.99306759 51.32591959
#  55.29953917 58.53658537 52.53940455 54.84460695 59.40594059 54.39709882
#  52.77044855 58.70841487 55.60704356 61.98347107 73.34963325 69.76744186
#  50.80440305 55.50416281 58.3090379  53.42831701 53.52363961 58.47953216
#  56.39097744 56.39097744 60.36217304 57.36137667 57.2519084  59.05511811
#  57.36137667 57.2519084  59.76095618 60.24096386 56.76442763 58.42259007
#  59.34718101 55.40166205 55.76208178 57.74783446 55.40166205 55.97014925
#  58.0270793  55.81395349 55.76208178 58.82352941 54.59508644 54.74452555
#  58.08325266 56.17977528 55.60704356 56.9259962  54.00540054 56.98005698
#  58.70841487 56.02240896 58.0270793  58.47953216 57.2519084  59.28853755
#  58.59375    55.81395349 59.05511811 59.70149254 56.60377358 57.85920926
#  59.11330049]

# %%
plt.plot(HR)

# %%
#filtracja (opcjonalnie) HR
Wn = 0.2 #dobierz eksperymentalnie
b2, a2 = scipy.signal.butter(4, Wn, btype='lowpass') 
HR_filt = scipy.signal.filtfilt(b2, a2, HR)
plt.plot(HR)
plt.plot(HR_filt)

# %%
#obliczenie HRV - odchylenie standardowe dla HR (niefiltrowane)
HRV = np.std(HR)
print(HRV)
# Out:
# 4.035466366905536

# %%
#Szacowany wydatek energetyczny na podstawie HR (wg Keytel et al.)
ee_kj_min = -59.3954 + 0.45 * HR
ee_kcal_min = ee_kj_min / 4.184

# %%
plt.plot(ee_kcal_min)
