# %% [markdown]
# ## Lab. 1 - Student

# %% [markdown]
# ## Zadanie 1
#
# Wygeneruj sinusoidę:
# - amplituda = 2
# - częstotliwość = 7 Hz
# - czas trwania = 2 s
# - fs = 500 Hz

# %%
#miejsce na kod

# %% [markdown]
# ## Zadanie 2
#
# Dodaj szum gaussowski i porównaj wykresy.

# %%
#miejsce na kod

# %% [markdown]
# ## Zadanie 3
#
# Utwórz sygnał będący sumą trzech częstotliwości:
# - 3 Hz
# - 15 Hz
# - 40 Hz

# %%
#miejsce na kod
