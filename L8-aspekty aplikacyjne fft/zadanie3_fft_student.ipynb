# %% [markdown]
# # Zadanie 3 – Okna i EEG

# %% [markdown]
# ## Cel
# Porównanie okien w analizie widma.
#
# ## Polecenie
# 1. Wygeneruj sygnał:
# - 10 Hz (alpha)
# - 20 Hz (beta)
# - szum
#
# 2. Zastosuj:
# - brak okna
# - Hann
# - Blackman
#
# 3. Porównaj FFT
#
# ## Pytania
# - Które okno daje najmniejszy przeciek?
# - Jak zmienia się szerokość piku?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import rfft, rfftfreq

# %%
# miejsce na kod
