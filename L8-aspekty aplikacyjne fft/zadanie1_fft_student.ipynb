# %% [markdown]
# # Zadanie 1 – Rozdzielczość widma (EKG)

# %% [markdown]
# ## Cel
# Zbadaj wpływ długości sygnału na rozdzielczość widma i dokładność estymacji HR.
#
# ## Polecenie
# 1. Wygeneruj sygnał EKG (np. sinus ~1.2 Hz + szum)
# 2. Wytnij fragmenty:
# - 2 s
# - 5 s
# - 10 s
#
# 3. Dla każdego:
# - policz FFT
# - znajdź dominującą częstotliwość
# - przelicz na BPM
#
# ## Pytania
# - Jak zmienia się Δf?
# - Jak zmienia się dokładność HR?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import rfft, rfftfreq
from scipy.signal import butter, filtfilt

# %%
fs = 100
To = [2, 5, 10]

# %%
# miejsce na kod
