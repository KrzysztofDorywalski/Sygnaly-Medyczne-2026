# %% [markdown]
# # Zadanie 2 – Przeciek widma (oddech)

# %% [markdown]
# ## Cel
# Zrozumienie przecieku widma.
#
# ## Polecenie
# 1. Wygeneruj sygnał: sin(2π·0.25·t)
# 2. Użyj długości:
# - 8 s
# - 10 s
# - 12 s
#
# 3. Porównaj FFT
#
# ## Pytania
# - Kiedy pojawia się przeciek?
# - Dlaczego?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import rfft, rfftfreq
from scipy.signal import butter, filtfilt
